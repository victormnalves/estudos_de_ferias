# %%
aba = 5

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
a_list = ['foo',2,[4,5]]

# %%
a_list[2]
# Out:
# [4, 5]

# %%
a_list[2] = (3,4)

# %%
a_list
# Out:
# ['foo', 2, (3, 4)]
